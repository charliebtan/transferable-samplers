# %%
# %load_ext autoreload
# %autoreload 2
import logging
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from bgflow.utils import (assert_numpy, distance_vectors, distances_from_vectors, 
                          remove_mean, IndexBatchIterator, LossReporter, as_numpy, compute_distances
)
from bgflow import (GaussianMCMCSampler, DiffEqFlow, BoltzmannGenerator, Energy, Sampler, 
                    MultiDoubleWellPotential, MeanFreeNormalDistribution, 
                    KernelDynamics,BlackBoxDynamics, TimeIndependentDynamics, BruteForceEstimator, HutchinsonEstimator, DenseNet)

from bgflow.utils.autograd import brute_force_jacobian_trace

from tbg.gcl import E_GCL_vel, E_GCL, GCL
from tbg.models2 import EGNN
from ema_pytorch import EMA

import os
import time
import zuko

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


# first define system dimensionality and a target energy/distribution

dim = 8
n_particles = 4
n_dimensions = dim // n_particles

# DW parameters
a=0.9
b=-4
c=0
offset=4

target = MultiDoubleWellPotential(dim, n_particles, a, b, c, offset, two_event_dims=False)

# define a MCMC sampler to sample from the target energy

dw4_data = np.load("../data/dw4-dataidx.npy", allow_pickle=True)
all_data = remove_mean(dw4_data[0], n_particles, n_dimensions)
idx = dw4_data[1]
data = all_data[idx[:100000]]
val_data = all_data[idx[100000:500000]]
data_holdout = all_data[idx[-500000:]]
data_holdout.shape

dists_data = as_numpy(compute_distances(data, n_particles, n_dimensions))

#plt.hist(dists_data.reshape(-1), bins=100);

# %%
n_data = 100000
data_smaller = data[:n_data].clone()
dists_data = as_numpy(compute_distances(data_smaller, n_particles, n_dimensions))
sample_dir = "sample/2d_nf"
model_dir = "models/2d_nf"
fig_dir = "figs/2d_nf"

os.makedirs(sample_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(fig_dir, exist_ok=True)

# %%
# # now set up a prior
# prior =  MeanFreeNormalDistribution(dim, n_particles, two_event_dims=False).cuda()

# now set up a prior
class MyMeanFreeNormalDistribution(Energy, Sampler):
    """ Mean-free normal distribution. """

    def __init__(self, dim, n_particles, std=1., two_event_dims=True):
        if two_event_dims:
            super().__init__([n_particles, dim // n_particles])
        else:
            super().__init__(dim)
        self._two_event_dims = two_event_dims
        self._dim = dim
        self._n_particles = n_particles
        self._spacial_dims = dim // n_particles
        self.register_buffer("_std", torch.as_tensor(std))

    def forward(self, n_samples, temperature=1.):
        samples = self.sample(n_samples, temperature)
        energy = 0.5 * samples.pow(2).sum(dim=-1, keepdim=True) / self._std ** 2
        return samples, energy.squeeze()
        
    def _energy(self, x):
        x = self._remove_mean(x).view(-1, self._dim)
        # TODO: make consistent
        return 0.5 * x.pow(2).sum(dim=-1, keepdim=True) / self._std ** 2

    def sample(self, n_samples, temperature=1.):
        x = torch.ones((n_samples, self._n_particles, self._spacial_dims), dtype=self._std.dtype,
                         device=self._std.device).normal_(mean=0, std=self._std)
        x = self._remove_mean(x)
        if not self._two_event_dims:
            x = x.view(-1, self._dim)
        return x

    def _remove_mean(self, x):
        x = x.view(-1, self._n_particles, self._spacial_dims)
        x = x - torch.mean(x, dim=1, keepdim=True)
        return x



prior =  MyMeanFreeNormalDistribution(dim, n_particles, two_event_dims=False).cuda()

# %%
from tarflow import Model
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

img_size = 8
channel_size = 1

# we use a small model for fast demonstration, increase the model size for better results
patch_size = 8
channels = 64
blocks = 4
layers_per_block = 4

n_epochs=500
dim = 8
flow = Model(in_channels=channel_size, img_size=img_size, patch_size=patch_size, 
              channels=channels, num_blocks=blocks, layers_per_block=layers_per_block).to(device)
ema_flow = Model(in_channels=channel_size, img_size=img_size, patch_size=patch_size, 
              channels=channels, num_blocks=blocks, layers_per_block=layers_per_block).to(device)

ema = EMA(
    flow,
    beta = 0.999,              # exponential moving average factor
    update_after_step = 5_000,    # only after this number of .update() calls will it start updating
    update_every = 1,          # how often to actually update, to save on compute (updates every 10th .update() call)
)

optimizer = torch.optim.AdamW(flow.parameters(), 1e-4)
# Out:
# 8 8 1
# 8 8 1

# %%
n_batch = 512
batch_iter = IndexBatchIterator(len(data_smaller), n_batch)

def train():
    i = 0
    for epoch in range(n_epochs):
        for it, idxs in enumerate(batch_iter):
            optimizer.zero_grad()
            x_1 = data_smaller[idxs].cuda()
            #loss = - flow().log_prob(x_1).mean()
            z, _, logdets = flow(x_1)
            loss = flow.get_loss(z, logdets)
            if torch.isnan(loss) or torch.isinf(loss):
                loss *= 0.
            loss.backward()
            torch.nn.utils.clip_grad_norm_(flow.parameters(), 1.0)
            torch.nn.utils.clip_grad_value_(flow.parameters(), 1.0)
            optimizer.step()
            ema.update()
            i += 1
        if (epoch + 1) % 2 == 0:
                ema_state_dict = {k.replace("ema_model.transform.", "transform.").replace("ema_model.base.", "base."): v for k, v in ema.state_dict().items()}
                ema_flow.load_state_dict(ema_state_dict, strict=False)
                z, _, logdets = ema_flow(x_1)
                ema_loss = ema_flow.get_loss(z, logdets)
                print(f"Step [{epoch+1}/{n_epochs}] - Loss: {loss.item():.4f} - EMA Loss: {ema_loss.item():.4f}")

ema_flow_path = model_dir + f'/ema_flow_tar_v5.pth'
flow_path = model_dir + f'/flow_tar_v5.pth'

if not os.path.exists(flow_path): # if no saved model, train
    train()
    torch.save(flow.state_dict(), flow_path)
    logging.info(f"Model saved to {flow_path}")
    torch.save(ema_flow.state_dict(), ema_flow_path)
    logging.info(f"Model saved to {ema_flow_path}")
else:
    # load saved model
    flow.load_state_dict(torch.load(flow_path))
    logging.info(f"Model loaded from {flow_path}")
    ema_flow.load_state_dict(torch.load(ema_flow_path))
    logging.info(f"Model loaded from {ema_flow_path}")
# Out:
# Step [2/500] - Loss: -3.7207 - EMA Loss: 1.6319
# Step [4/500] - Loss: -4.0328 - EMA Loss: 1.6832
# Step [6/500] - Loss: -4.5020 - EMA Loss: 1.6909
# Step [8/500] - Loss: -4.8775 - EMA Loss: 1.6771
# Step [10/500] - Loss: -5.6970 - EMA Loss: 1.6173
# Step [12/500] - Loss: -6.3859 - EMA Loss: 1.6572
# Step [14/500] - Loss: -5.7920 - EMA Loss: 1.7330
# Step [16/500] - Loss: -6.3648 - EMA Loss: 1.7018
# Step [18/500] - Loss: -6.6040 - EMA Loss: 1.6252
# Step [20/500] - Loss: -7.2294 - EMA Loss: 1.6565
# Step [22/500] - Loss: -7.3097 - EMA Loss: 1.7020
# Step [24/500] - Loss: -7.4905 - EMA Loss: 1.6863
# Step [26/500] - Loss: -8.2186 - EMA Loss: 1.6228
# Step [28/500] - Loss: -7.9804 - EMA Loss: 1.6918
# Step [30/500] - Loss: -7.7710 - EMA Loss: 1.6173
# Step [32/500] - Loss: -8.3561 - EMA Loss: 1.6780
# Step [34/500] - Loss: -9.1692 - EMA Loss: 1.6336
# Step [36/500] - Loss: -8.5021 - EMA Loss: 1.6482
# Step [38/500] - Loss: -9.5589 - EMA Loss: 1.6718
# Step [40/500] - Loss: -9.5473 - EMA Loss: 1.7400
# Step [42/500] - Loss: -9.5998 - EMA Loss: 1.6256
# Step [44/500] - Loss: -9.9192 - EMA Loss: 1.6319
# Step [46/500] - Loss: -9.6400 - EMA Loss: 1.6856
# Step [48/500] - Loss: -9.4214 - EMA Loss: 1.6842
# Step [50/500] - Loss: -9.9071 - EMA Loss: 1.7183
# Step [52/500] - Loss: -9.8434 - EMA Loss: 1.7495
# Step [54/500] - Loss: -10.3892 - EMA Loss: 1.6838
# Step [56/500] - Loss: -10.2900 - EMA Loss: 1.6694
# Step [58/500] - Loss: -10.3790 - EMA Loss: 1.6587
# Step [60/500] - Loss: -10.8624 - EMA Loss: 1.6623
# Step [62/500] - Loss: -10.8955 - EMA Loss: 1.6501
# Step [64/500] - Loss: -11.0625 - EMA Loss: 1.6666
# Step [66/500] - Loss: -10.4084 - EMA Loss: 1.6979
# Step [68/500] - Loss: -10.7713 - EMA Loss: 1.6278
# Step [70/500] - Loss: -11.0704 - EMA Loss: 1.6679
# Step [72/500] - Loss: -11.1868 - EMA Loss: 1.6083
# Step [74/500] - Loss: -11.1884 - EMA Loss: 1.6772
# Step [76/500] - Loss: -11.0763 - EMA Loss: 1.6489
# Step [78/500] - Loss: -11.9896 - EMA Loss: 1.6988
# Step [80/500] - Loss: -11.0521 - EMA Loss: 1.6833
# Step [82/500] - Loss: -11.5020 - EMA Loss: 1.5891
# Step [84/500] - Loss: -11.2144 - EMA Loss: 1.7121
# Step [86/500] - Loss: -11.8073 - EMA Loss: 1.7019
# Step [88/500] - Loss: -11.8063 - EMA Loss: 1.6636
# Step [90/500] - Loss: -11.5603 - EMA Loss: 1.6721
# Step [92/500] - Loss: -11.8220 - EMA Loss: 1.6446
# Step [94/500] - Loss: nan - EMA Loss: 1.6446
# Step [96/500] - Loss: nan - EMA Loss: 1.5959
# Step [98/500] - Loss: nan - EMA Loss: 1.5772
# Step [100/500] - Loss: nan - EMA Loss: 1.6286
# Step [102/500] - Loss: nan - EMA Loss: 1.6439
# Step [104/500] - Loss: nan - EMA Loss: 1.7026
# Step [106/500] - Loss: nan - EMA Loss: 1.6674
# Step [108/500] - Loss: nan - EMA Loss: 1.6159
# Step [110/500] - Loss: nan - EMA Loss: 1.6638
# Step [112/500] - Loss: nan - EMA Loss: 1.6443
# Step [114/500] - Loss: nan - EMA Loss: 1.6303
# Step [116/500] - Loss: nan - EMA Loss: 1.6363
# Step [118/500] - Loss: nan - EMA Loss: 1.6367
# Step [120/500] - Loss: nan - EMA Loss: 1.6777
# Step [122/500] - Loss: nan - EMA Loss: 1.7035
# Step [124/500] - Loss: nan - EMA Loss: 1.6704
# Step [126/500] - Loss: nan - EMA Loss: 1.7066
# Step [128/500] - Loss: nan - EMA Loss: 1.6592
# Step [130/500] - Loss: nan - EMA Loss: 1.6636
# Step [132/500] - Loss: nan - EMA Loss: 1.5900
# Step [134/500] - Loss: nan - EMA Loss: 1.6810
# Step [136/500] - Loss: nan - EMA Loss: 1.6900
# Step [138/500] - Loss: nan - EMA Loss: 1.6794
# Step [140/500] - Loss: nan - EMA Loss: 1.7133
# Step [142/500] - Loss: nan - EMA Loss: 1.6278
# Step [144/500] - Loss: nan - EMA Loss: 1.7059
# Step [146/500] - Loss: nan - EMA Loss: 1.7043
# Step [148/500] - Loss: nan - EMA Loss: 1.7326
# Step [150/500] - Loss: nan - EMA Loss: 1.7354
# Step [152/500] - Loss: nan - EMA Loss: 1.6742
# Step [154/500] - Loss: nan - EMA Loss: 1.5802
# Step [156/500] - Loss: nan - EMA Loss: 1.6251
# Step [158/500] - Loss: nan - EMA Loss: 1.6850
# Step [160/500] - Loss: nan - EMA Loss: 1.7092
# Step [162/500] - Loss: nan - EMA Loss: 1.7242
# Step [164/500] - Loss: nan - EMA Loss: 1.6556
# Step [166/500] - Loss: nan - EMA Loss: 1.6093
# Step [198/500] - Loss: nan - EMA Loss: 1.7111
# Step [200/500] - Loss: nan - EMA Loss: 1.6598
# Step [202/500] - Loss: nan - EMA Loss: 1.6067
# Step [204/500] - Loss: nan - EMA Loss: 1.6586
# Step [206/500] - Loss: nan - EMA Loss: 1.7037
# Step [208/500] - Loss: nan - EMA Loss: 1.6064
# Step [210/500] - Loss: nan - EMA Loss: 1.6672
# Step [212/500] - Loss: nan - EMA Loss: 1.7166
# Step [214/500] - Loss: nan - EMA Loss: 1.6089
# Step [216/500] - Loss: nan - EMA Loss: 1.6806
# Step [218/500] - Loss: nan - EMA Loss: 1.6127
# Step [220/500] - Loss: nan - EMA Loss: 1.6337
# Step [222/500] - Loss: nan - EMA Loss: 1.6300
# Step [224/500] - Loss: nan - EMA Loss: 1.6969
# Step [226/500] - Loss: nan - EMA Loss: 1.6081
# Step [228/500] - Loss: nan - EMA Loss: 1.6701
# Step [230/500] - Loss: nan - EMA Loss: 1.6774
# Step [232/500] - Loss: nan - EMA Loss: 1.6335
# Step [234/500] - Loss: nan - EMA Loss: 1.6589
# Step [236/500] - Loss: nan - EMA Loss: 1.6446
# Step [238/500] - Loss: nan - EMA Loss: 1.6487
# Step [240/500] - Loss: nan - EMA Loss: 1.5469
# Step [242/500] - Loss: nan - EMA Loss: 1.6350
# Step [244/500] - Loss: nan - EMA Loss: 1.6352
# Step [246/500] - Loss: nan - EMA Loss: 1.6546
# Step [248/500] - Loss: nan - EMA Loss: 1.6935
# Step [250/500] - Loss: nan - EMA Loss: 1.6228
# Step [252/500] - Loss: nan - EMA Loss: 1.6198
# Step [254/500] - Loss: nan - EMA Loss: 1.6966
# Step [256/500] - Loss: nan - EMA Loss: 1.6820
# Step [258/500] - Loss: nan - EMA Loss: 1.6587
# Step [260/500] - Loss: nan - EMA Loss: 1.6550
# Step [262/500] - Loss: nan - EMA Loss: 1.6793
# Step [264/500] - Loss: nan - EMA Loss: 1.6617
# Step [266/500] - Loss: nan - EMA Loss: 1.6312
# Step [268/500] - Loss: nan - EMA Loss: 1.7100
# Step [270/500] - Loss: nan - EMA Loss: 1.6363
# Step [272/500] - Loss: nan - EMA Loss: 1.6441
# Step [274/500] - Loss: nan - EMA Loss: 1.6203
# Step [276/500] - Loss: nan - EMA Loss: 1.6366
# Step [278/500] - Loss: nan - EMA Loss: 1.6392
# Step [280/500] - Loss: nan - EMA Loss: 1.6658
# Step [282/500] - Loss: nan - EMA Loss: 1.6965
# Step [284/500] - Loss: nan - EMA Loss: 1.6561
# Step [286/500] - Loss: nan - EMA Loss: 1.6887
# Step [288/500] - Loss: nan - EMA Loss: 1.6890
# Step [290/500] - Loss: nan - EMA Loss: 1.6759
# Step [292/500] - Loss: nan - EMA Loss: 1.6530
# Step [294/500] - Loss: nan - EMA Loss: 1.6840
# Step [296/500] - Loss: nan - EMA Loss: 1.6995
# Step [298/500] - Loss: nan - EMA Loss: 1.7077
# Step [300/500] - Loss: nan - EMA Loss: 1.6779
# Step [302/500] - Loss: nan - EMA Loss: 1.6564
# Step [304/500] - Loss: nan - EMA Loss: 1.6596
# Step [306/500] - Loss: nan - EMA Loss: 1.7003
# Step [308/500] - Loss: nan - EMA Loss: 1.6329
# Step [310/500] - Loss: nan - EMA Loss: 1.6282
# Step [312/500] - Loss: nan - EMA Loss: 1.7118
# Step [314/500] - Loss: nan - EMA Loss: 1.7116
# Step [316/500] - Loss: nan - EMA Loss: 1.6364
# Step [318/500] - Loss: nan - EMA Loss: 1.6919
# Step [320/500] - Loss: nan - EMA Loss: 1.6448
# Step [322/500] - Loss: nan - EMA Loss: 1.6209
# Step [324/500] - Loss: nan - EMA Loss: 1.6879
# Step [326/500] - Loss: nan - EMA Loss: 1.6929
# Step [328/500] - Loss: nan - EMA Loss: 1.6614
# Step [330/500] - Loss: nan - EMA Loss: 1.6935
# Step [332/500] - Loss: nan - EMA Loss: 1.6628
# Step [334/500] - Loss: nan - EMA Loss: 1.6095
# Step [336/500] - Loss: nan - EMA Loss: 1.6637
# Step [338/500] - Loss: nan - EMA Loss: 1.6404
# Step [340/500] - Loss: nan - EMA Loss: 1.6503
# Step [342/500] - Loss: nan - EMA Loss: 1.6053
# Step [344/500] - Loss: nan - EMA Loss: 1.6629
# Step [346/500] - Loss: nan - EMA Loss: 1.6916
# Step [348/500] - Loss: nan - EMA Loss: 1.7008
# Step [350/500] - Loss: nan - EMA Loss: 1.6998
# Step [352/500] - Loss: nan - EMA Loss: 1.6742
# Step [354/500] - Loss: nan - EMA Loss: 1.6670
# Step [356/500] - Loss: nan - EMA Loss: 1.6806
# Step [358/500] - Loss: nan - EMA Loss: 1.6275
# Step [360/500] - Loss: nan - EMA Loss: 1.6424
# Step [362/500] - Loss: nan - EMA Loss: 1.6811
# Step [364/500] - Loss: nan - EMA Loss: 1.6471
# Step [366/500] - Loss: nan - EMA Loss: 1.6966
# Step [368/500] - Loss: nan - EMA Loss: 1.6505
# Step [370/500] - Loss: nan - EMA Loss: 1.6774
# Step [372/500] - Loss: nan - EMA Loss: 1.6681
# Step [374/500] - Loss: nan - EMA Loss: 1.6584
# Step [376/500] - Loss: nan - EMA Loss: 1.6935
# Step [378/500] - Loss: nan - EMA Loss: 1.6318
# Step [380/500] - Loss: nan - EMA Loss: 1.6089
# Step [382/500] - Loss: nan - EMA Loss: 1.6669
# Step [384/500] - Loss: nan - EMA Loss: 1.6567
# Step [386/500] - Loss: nan - EMA Loss: 1.7513
# Step [388/500] - Loss: nan - EMA Loss: 1.7046
# Step [390/500] - Loss: nan - EMA Loss: 1.5898
# Step [392/500] - Loss: nan - EMA Loss: 1.6828
# Step [394/500] - Loss: nan - EMA Loss: 1.6888
# Step [396/500] - Loss: nan - EMA Loss: 1.6526
# Step [398/500] - Loss: nan - EMA Loss: 1.6878
# Step [400/500] - Loss: nan - EMA Loss: 1.6416
# Step [402/500] - Loss: nan - EMA Loss: 1.6702
# Step [404/500] - Loss: nan - EMA Loss: 1.5872
# Step [406/500] - Loss: nan - EMA Loss: 1.5669
# Step [408/500] - Loss: nan - EMA Loss: 1.7126
# Step [410/500] - Loss: nan - EMA Loss: 1.6641
# Step [412/500] - Loss: nan - EMA Loss: 1.6440
# Step [414/500] - Loss: nan - EMA Loss: 1.6512
# Step [416/500] - Loss: nan - EMA Loss: 1.5795
# Step [418/500] - Loss: nan - EMA Loss: 1.5923
# Step [420/500] - Loss: nan - EMA Loss: 1.7221
# Step [422/500] - Loss: nan - EMA Loss: 1.6393
# Step [424/500] - Loss: nan - EMA Loss: 1.6625
# Step [426/500] - Loss: nan - EMA Loss: 1.6740
# Step [428/500] - Loss: nan - EMA Loss: 1.6514
# Step [430/500] - Loss: nan - EMA Loss: 1.6218
# Step [432/500] - Loss: nan - EMA Loss: 1.6786
# Step [434/500] - Loss: nan - EMA Loss: 1.6608
# Step [436/500] - Loss: nan - EMA Loss: 1.6780
# Step [438/500] - Loss: nan - EMA Loss: 1.6195
# Step [440/500] - Loss: nan - EMA Loss: 1.6777
# Step [442/500] - Loss: nan - EMA Loss: 1.6592
# Step [444/500] - Loss: nan - EMA Loss: 1.6207
# Step [446/500] - Loss: nan - EMA Loss: 1.6367
# Step [448/500] - Loss: nan - EMA Loss: 1.6639
# Step [450/500] - Loss: nan - EMA Loss: 1.6551
# Step [452/500] - Loss: nan - EMA Loss: 1.6857
# Step [454/500] - Loss: nan - EMA Loss: 1.7036
# Step [456/500] - Loss: nan - EMA Loss: 1.6800
# Step [458/500] - Loss: nan - EMA Loss: 1.7188
# Step [460/500] - Loss: nan - EMA Loss: 1.6743
# Step [462/500] - Loss: nan - EMA Loss: 1.6563
# Step [464/500] - Loss: nan - EMA Loss: 1.6818
# Step [466/500] - Loss: nan - EMA Loss: 1.6972
# Step [468/500] - Loss: nan - EMA Loss: 1.6984
# Step [470/500] - Loss: nan - EMA Loss: 1.6428
# Step [472/500] - Loss: nan - EMA Loss: 1.6798
# Step [474/500] - Loss: nan - EMA Loss: 1.7010
# Step [476/500] - Loss: nan - EMA Loss: 1.6663
# Step [478/500] - Loss: nan - EMA Loss: 1.6821
# Step [480/500] - Loss: nan - EMA Loss: 1.6842
# Step [482/500] - Loss: nan - EMA Loss: 1.5876
# Step [484/500] - Loss: nan - EMA Loss: 1.5942
# Step [486/500] - Loss: nan - EMA Loss: 1.6776
# Step [488/500] - Loss: nan - EMA Loss: 1.6885
# Step [490/500] - Loss: nan - EMA Loss: 1.6828
# Step [492/500] - Loss: nan - EMA Loss: 1.6439
# Step [494/500] - Loss: nan - EMA Loss: 1.6542
# Step [496/500] - Loss: nan - EMA Loss: 1.6685
# Step [498/500] - Loss: nan - EMA Loss: 1.6952
# 2025-01-07 20:53:40,524 - INFO - Model saved to models/2d_nf/flow_tar_v5.pth
# 2025-01-07 20:53:40,540 - INFO - Model saved to models/2d_nf/ema_flow_tar_v5.pth
# Step [500/500] - Loss: nan - EMA Loss: 1.6949

# %%
#x0 = prior.sample(10000)
#ema_state_dict = {k.replace("ema_model.transform.", "transform.").replace("ema_model.base.", "base."): v for k, v in ema.state_dict().items()}
x1 = flow().sample((100000,))
log_probs = flow().log_prob(x1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #x0 = prior.sample(10000)
#       2 #ema_state_dict = {k.replace("ema_model.transform.", "transform.").replace("ema_model.base.", "base."): v for k, v in ema.state_dict().items()}
# ----> 3 x1 = flow().sample((100000,))
#       4 log_probs = flow().log_prob(x1)
#
# File /network/scratch/a/alexander.tong/micromamba/envs/tbg3/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /network/scratch/a/alexander.tong/micromamba/envs/tbg3/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# TypeError: Model.forward() missing 1 required positional argument: 'x'

# %%
energies_data = target.energy(data).detach().cpu().numpy()
#energies_compare = sampls.energy()
energies_bg = target.energy(x1).detach().cpu().numpy().flatten()
print(energies_bg.shape)
log_weights = - energies_bg - log_probs.detach().cpu().numpy()
#log_weights = bg.log_weights_given_latent(x1, x0, dlogp1.reshape(-1,1), normalize=False).detach().cpu().numpy()
log_w_np = as_numpy(log_weights)
energies_prior = target.energy(data).detach().cpu().numpy()
print(np.exp(log_w_np).shape)
min_energy = min(energies_data.min(), energies_bg.min(), energies_prior.min())
max_energy = max(energies_data.max(), energies_bg.max(), energies_prior.max())

plt.figure(figsize=(13,8))
efac = 1
#plt.hist(energies_prior, bins=100, density=True, range=(min_energy, 0), alpha=0.4, color="b", histtype='step', linewidth=4,
#         label="prior");
plt.hist(energies_data, bins=100, density=True, range=(min_energy, 0), alpha=0.4, color="g", histtype='step', linewidth=4, 
         label="Target");
plt.hist(energies_bg, bins=100, density=True,  range=(min_energy, 0), alpha=0.4, histtype='step', linewidth=4,
         color="r", label=f"BG samples");

plt.hist(energies_bg.reshape(-1), bins=100, density=True,  range=(min_energy, 0), alpha=0.4, histtype='step', linewidth=4,
         color="b", label=f"Weighted BG samples", weights=np.exp(log_w_np));
#plt.hist(energies_compare, bins=100, density=True, range=(energies_bg.min(), 0), alpha=0.4, color="y", 
#         label="MCMC data (test)");
plt.title("DW4 Energy distribution", fontsize=45)
plt.xlabel("u(x)", fontsize=45)  
plt.xticks(fontsize=45) 
plt.yticks(fontsize=45);
plt.legend(fontsize=25);

# %%
energies_bg

# %%
energies_data
